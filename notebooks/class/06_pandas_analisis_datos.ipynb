# %% [markdown]
# # 🐼 Pandas: Análisis de Datos - Parte 1
#
# ## 🎯 Objetivos de Aprendizaje
#
# Al finalizar este notebook, serás capaz de:
#
# - Comprender qué es Pandas y su importancia en Data Science
# - Trabajar con las estructuras de datos fundamentales: Series y DataFrames
# - Cargar y explorar datasets desde diferentes fuentes
# - Realizar operaciones básicas de manipulación de datos
# - Filtrar, seleccionar y indexar datos de manera eficiente
# - Aplicar funciones de agregación y estadísticas descriptivas
# - Manejar datos faltantes (missing data)
#
# ## 📚 Contenido
#
# 1. **Introducción a Pandas**
#    - ¿Qué es Pandas?
#    - Ventajas para análisis de datos
#    - Instalación e importación
#
# 2. **Estructuras de Datos en Pandas**
#    - **Series**: Arrays unidimensionales con etiquetas
#    - **DataFrame**: Estructuras bidimensionales (como tablas)
#
# 3. **Carga de Datos**
#    - Lectura desde archivos CSV
#    - Lectura desde Excel
#    - Otras fuentes de datos
#
# 4. **Exploración Inicial de Datos**
#    - Métodos `head()`, `tail()`, `info()`
#    - Estadísticas descriptivas con `describe()`
#    - Forma y dimensiones del dataset
#
# 5. **Indexación y Selección**
#    - Selección por etiquetas (`loc`)
#    - Selección por posición (`iloc`)
#    - Selección de columnas y filas específicas
#
# 6. **Filtrado de Datos**
#    - Filtros condicionales
#    - Múltiples condiciones
#    - Método `query()`
#
# 7. **Operaciones Básicas**
#    - Agregaciones: `sum()`, `mean()`, `count()`
#    - Operaciones por columnas
#    - Creación de nuevas columnas
#
# 8. **Manejo de Datos Faltantes**
#    - Identificación con `isnull()` y `isna()`
#    - Eliminación con `dropna()`
#    - Imputación con `fillna()`
#
# ## 🛠️ Prerrequisitos
#
# - Conocimiento sólido de Python (listas, diccionarios, funciones)
# - Familiaridad con NumPy (recomendado)
# - Conceptos básicos de análisis de datos
#
# ## 📦 Librería Utilizada
#
# ```python
# import pandas as pd
# import numpy as np  # Complementario para operaciones numéricas
# ```
#
# ## 💡 Conceptos Clave
#
# - **Series**: Estructura unidimensional similar a una columna de Excel
# - **DataFrame**: Estructura bidimensional similar a una hoja de cálculo
# - **Index**: Etiquetas para identificar filas y columnas
# - **Missing Data**: Datos faltantes o nulos en el dataset
# - **Aggregation**: Operaciones que resumen múltiples valores en uno solo
#
# ## 🌟 ¿Por qué Pandas?
#
# - **Facilidad de uso**: Sintaxis intuitiva para manipulación de datos
# - **Rendimiento**: Operaciones optimizadas para grandes datasets
# - **Flexibilidad**: Manejo de diferentes tipos de datos (numéricos, texto, fechas)
# - **Integración**: Compatible con todo el ecosistema científico de Python
# - **Funcionalidad**: Herramientas completas para limpieza y transformación de datos
#
# ## 📁 Estructura de Datos de Ejemplo
#
# Durante este notebook trabajaremos con datasets reales para ejemplificar cada concepto con casos prácticos.
#
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv('http://cdn.buenosaires.gob.ar/datosabiertos/datasets/sueldo-funcionarios/sueldo_funcionarios_2019.csv')

# %%
df.head(2)
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0  20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1  20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
#
#                 reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 0          Jefe de Gobierno                197745.8           0.0
# 1  Vicejefatura de Gobierno                197745.8           0.0
#
#    total_salario_bruto_i_+_ii observaciones
# 0                    197745.8           NaN
# 1                    197745.8           NaN

# %%
df.tail(2)
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 383  20-30593774-7  2019   12           AVELLANEDA   PATRICIO IGNACIO
# 384  27-27011181-0  2019   12            FERNANDEZ     KARINA BEATRIZ
#
#                                            reparticion  \
# 383  SECR Planificación, Evaluación y Coordinación ...
# 384                          SECR Asuntos Estratégicos
#
#      asignacion_por_cargo_i  aguinaldo_ii  total_salario_bruto_i_+_ii  \
# 383               249972.86     124986.43                   374959.29
# 384               187539.45      15628.29                   203167.74
#
#            observaciones
# 383                  NaN
# 384  alta desde el 10/12

# %%
df.sample(2)
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 280  20-31164337-2  2019    9         DI BENEDETTO           FEDERICO
# 247  20-25567686-6  2019    8              BENEGAS           FERNANDO
#
#                    reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 280            SS Comunicacion               249972.87           0.0
# 247  SECR Coordinación General               239470.36           0.0
#
#      total_salario_bruto_i_+_ii observaciones
# 280                   249972.87           NaN
# 247                   239470.36           NaN

# %%
df.columns
# Out:
# Index(['cuil', 'anio', 'mes', 'funcionario_apellido', 'funcionario_nombre',
#        'reparticion', 'asignacion_por_cargo_i', 'aguinaldo_ii',
#        'total_salario_bruto_i_+_ii', 'observaciones'],
#       dtype='object')

# %%
df.describe()
# Out:
#          anio         mes  asignacion_por_cargo_i   aguinaldo_ii  \
# count   385.0  385.000000              385.000000     385.000000
# mean   2019.0    6.631169           234234.368000   20282.084883
# std       0.0    3.539077            35043.160085   45248.840725
# min    2019.0    1.000000            74991.860000       0.000000
# 25%    2019.0    4.000000           224516.620000       0.000000
# 50%    2019.0    7.000000           239470.360000       0.000000
# 75%    2019.0   10.000000           249972.870000       0.000000
# max    2019.0   12.000000           275089.750000  170855.560000
#
#        total_salario_bruto_i_+_ii
# count                  385.000000
# mean                254516.452883
# std                  51434.987870
# min                 185396.540000
# 25%                 224516.620000
# 50%                 245811.620000
# 75%                 263531.980000
# max                 445945.310000

# %%
df.shape
# Out:
# (385, 10)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=385, step=1)

# %%
df.columns
# Out:
# Index(['cuil', 'anio', 'mes', 'funcionario_apellido', 'funcionario_nombre',
#        'reparticion', 'asignacion_por_cargo_i', 'aguinaldo_ii',
#        'total_salario_bruto_i_+_ii', 'observaciones'],
#       dtype='object')

# %%
df[ df['mes'] == 1].head(2)
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0  20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1  20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
#
#                 reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 0          Jefe de Gobierno                197745.8           0.0
# 1  Vicejefatura de Gobierno                197745.8           0.0
#
#    total_salario_bruto_i_+_ii observaciones
# 0                    197745.8           NaN
# 1                    197745.8           NaN

# %%
df[ df['mes'] < 6 ].head(2)
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0  20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1  20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
#
#                 reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 0          Jefe de Gobierno                197745.8           0.0
# 1  Vicejefatura de Gobierno                197745.8           0.0
#
#    total_salario_bruto_i_+_ii observaciones
# 0                    197745.8           NaN
# 1                    197745.8           NaN

# %%
df[ df.funcionario_apellido == 'RODRIGUEZ LARRETA']
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0    20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 32   20-17692128-6  2019    2    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 64   20-17692128-6  2019    3    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 95   20-17692128-6  2019    4    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 126  20-17692128-6  2019    5    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 157  20-17692128-6  2019    6    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 188  20-17692128-6  2019    7    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 219  20-17692128-6  2019    8    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 250  20-17692128-6  2019    9    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 281  20-17692128-6  2019   10    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 312  20-17692128-6  2019   11    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 366  20-17692128-6  2019   12    RODRIGUEZ LARRETA    HORACIO ANTONIO
#
#           reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 0    Jefe de Gobierno               197745.80          0.00
# 32   Jefe de Gobierno               197745.80          0.00
# 64   Jefe de Gobierno               217520.38          0.00
# 95   Jefe de Gobierno               217520.38          0.00
# 126  Jefe de Gobierno               217520.38          0.00
# 157  Jefe de Gobierno               228396.40     114198.20
# 188  Jefe de Gobierno               228396.40          0.00
# 219  Jefe de Gobierno               228396.40          0.00
# 250  Jefe de Gobierno               239816.22          0.00
# 281  Jefe de Gobierno               245811.62          0.00
# 312  Jefe de Gobierno               245811.62          0.00
# 366  Jefe de Gobierno               245811.62     122905.81
#
#      total_salario_bruto_i_+_ii observaciones
# 0                     197745.80           NaN
# 32                    197745.80           NaN
# 64                    217520.38           NaN
# 95                    217520.38           NaN
# 126                   217520.38           NaN
# 157                   342594.60           NaN
# 188                   228396.40           NaN
# 219                   228396.40           NaN
# 250                   239816.22           NaN
# 281                   245811.62           NaN
# 312                   245811.62           NaN
# 366                   368717.43           NaN

# %%
df[ (df.funcionario_apellido == 'RODRIGUEZ LARRETA') & (df.mes == 3) ]
# Out:
#              cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 64  20-17692128-6  2019    3    RODRIGUEZ LARRETA    HORACIO ANTONIO
#
#          reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 64  Jefe de Gobierno               217520.38           0.0
#
#     total_salario_bruto_i_+_ii observaciones
# 64                   217520.38           NaN

# %%
df.query(' mes == 12 & funcionario_apellido == "RODRIGUEZ LARRETA" ')
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 366  20-17692128-6  2019   12    RODRIGUEZ LARRETA    HORACIO ANTONIO
#
#           reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 366  Jefe de Gobierno               245811.62     122905.81
#
#      total_salario_bruto_i_+_ii observaciones
# 366                   368717.43           NaN

# %%
df[ df['funcionario_apellido'].str.contains('LARR') ]
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0    20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 23   20-26781618-3  2019    1                LARRE       PEDRO ANDRES
# 32   20-17692128-6  2019    2    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 55   20-26781618-3  2019    2                LARRE       PEDRO ANDRES
# 64   20-17692128-6  2019    3    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 95   20-17692128-6  2019    4    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 126  20-17692128-6  2019    5    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 157  20-17692128-6  2019    6    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 188  20-17692128-6  2019    7    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 219  20-17692128-6  2019    8    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 250  20-17692128-6  2019    9    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 281  20-17692128-6  2019   10    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 312  20-17692128-6  2019   11    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 366  20-17692128-6  2019   12    RODRIGUEZ LARRETA    HORACIO ANTONIO
#
#                                reparticion  asignacion_por_cargo_i  \
# 0                         Jefe de Gobierno               197745.80
# 23   SECR Ciencia, Tecnologia e Innovacion               204017.27
# 32                        Jefe de Gobierno               197745.80
# 55   SECR Ciencia, Tecnologia e Innovacion               204017.27
# 64                        Jefe de Gobierno               217520.38
# 95                        Jefe de Gobierno               217520.38
# 126                       Jefe de Gobierno               217520.38
# 157                       Jefe de Gobierno               228396.40
# 188                       Jefe de Gobierno               228396.40
# 219                       Jefe de Gobierno               228396.40
# 250                       Jefe de Gobierno               239816.22
# 281                       Jefe de Gobierno               245811.62
# 312                       Jefe de Gobierno               245811.62
# 366                       Jefe de Gobierno               245811.62
#
#      aguinaldo_ii  total_salario_bruto_i_+_ii   observaciones
# 0            0.00                   197745.80             NaN
# 23           0.00                   204017.27             NaN
# 32           0.00                   197745.80             NaN
# 55       34002.88                   238020.15  baja 28/2/2019
# 64           0.00                   217520.38             NaN
# 95           0.00                   217520.38             NaN
# 126          0.00                   217520.38             NaN
# 157     114198.20                   342594.60             NaN
# 188          0.00                   228396.40             NaN
# 219          0.00                   228396.40             NaN
# 250          0.00                   239816.22             NaN
# 281          0.00                   245811.62             NaN
# 312          0.00                   245811.62             NaN
# 366     122905.81                   368717.43             NaN

# %%
df_titanic = pd.read_csv('https://storage.googleapis.com/humai-datasets/aws_s3/analisis_de_datos/1_Indexing/titanic.csv',
                         sep='|')
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
# Cuantas personas sobrevivieron? 342, Cuantos hombres subieron al barco?, Cuantos hombres sobrevivieron?

# %% [markdown]
# Indexing

# %%
df.head(2)
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0  20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1  20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
#
#                 reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 0          Jefe de Gobierno                197745.8           0.0
# 1  Vicejefatura de Gobierno                197745.8           0.0
#
#    total_salario_bruto_i_+_ii observaciones
# 0                    197745.8           NaN
# 1                    197745.8           NaN

# %% [markdown]
# [start,stop,step]

# %%
df.iloc[10:20 , :]
# Out:
#              cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 10  20-24941711-5  2019    1                 MURA             MARTIN
# 11  20-21981279-6  2019    1        SCRENCI SILVA        BRUNO GUIDO
# 12  27-24030362-6  2019    1          TAGLIAFERRI          GUADALUPE
# 13  20-23864572-8  2019    1             STRAFACE     FERNANDO DIEGO
# 14  27-17593512-1  2019    1              MONTIEL      MARIA LETICIA
# 15  20-16891528-5  2019    1               NACHON      MARCELO JORGE
# 16  20-30593774-7  2019    1           AVELLANEDA   PATRICIO IGNACIO
# 17  20-29751476-9  2019    1             CARRILLO            FACUNDO
# 18  20-22366623-0  2019    1           COSTANTINO     SERGIO GABRIEL
# 19  20-24424714-9  2019    1         D'ALESSANDRO     MARCELO SILVIO
#
#                                           reparticion  asignacion_por_cargo_i  \
# 10                  Ministerio de Economía y Finanzas               224516.62
# 11                             Ministerio de Gobierno               224516.62
# 12          Ministerio de Hábitat y Desarrollo Humano               224516.62
# 13       SECR General y de Relaciones Internacionales               224516.62
# 14                               SECR Legal y Técnica               218659.66
# 15                                     SECR de Medios               218659.66
# 16  SECR Planificación, Evaluación y Coordinación ...               204017.27
# 17                  SECR Atención y Gestión Ciudadana               204017.27
# 18      SECR Integración Social Para Personas Mayores               204017.27
# 19                          SECR Justicia y Seguridad               204017.27
#
#     aguinaldo_ii  total_salario_bruto_i_+_ii observaciones
# 10           0.0                   224516.62           NaN
# 11           0.0                   224516.62           NaN
# 12           0.0                   224516.62           NaN
# 13           0.0                   224516.62           NaN
# 14           0.0                   218659.66           NaN
# 15           0.0                   218659.66           NaN
# 16           0.0                   204017.27           NaN
# 17           0.0                   204017.27           NaN
# 18           0.0                   204017.27           NaN
# 19           0.0                   204017.27           NaN

# %%
df.loc[: , ['mes','funcionario_nombre']]
# Out:
#      mes funcionario_nombre
# 0      1    HORACIO ANTONIO
# 1      1        DIEGO CESAR
# 2      1      MARIA SOLEDAD
# 3      1      GABRIEL MARIA
# 4      1       ENRIQUE LUIS
# ..   ...                ...
# 380   12          JUAN JOSE
# 381   12     FERNANDO DIEGO
# 382   12        BRUNO GUIDO
# 383   12   PATRICIO IGNACIO
# 384   12     KARINA BEATRIZ
#
# [385 rows x 2 columns]

# %% [markdown]
# <figure>
#   <img src='https://static.wixstatic.com/media/99d03c_7a2ee27525bd4bf7a534788fe924d4d1~mv2.jpg/v1/fill/w_364,h_337,al_c,lg_1,q_80,enc_avif,quality_auto/99d03c_7a2ee27525bd4bf7a534788fe924d4d1~mv2.jpg'>
#   <figcaption align='right'></figcaption>
# </figure>

# %%
df['mes'].count()
# Out:
# np.int64(385)

# %%
df['aguinaldo_ii'].mean()
# Out:
# np.float64(20282.084883116884)

# %%
df['aguinaldo_ii'].min()
# Out:
# 0.0

# %%
df['aguinaldo_ii'].max()
# Out:
# 170855.56

# %%
df['aguinaldo_ii'].sum()
# Out:
# np.float64(7808602.68)

# %%
df.describe()
# Out:
#          anio         mes  asignacion_por_cargo_i   aguinaldo_ii  \
# count   385.0  385.000000              385.000000     385.000000
# mean   2019.0    6.631169           234234.368000   20282.084883
# std       0.0    3.539077            35043.160085   45248.840725
# min    2019.0    1.000000            74991.860000       0.000000
# 25%    2019.0    4.000000           224516.620000       0.000000
# 50%    2019.0    7.000000           239470.360000       0.000000
# 75%    2019.0   10.000000           249972.870000       0.000000
# max    2019.0   12.000000           275089.750000  170855.560000
#
#        total_salario_bruto_i_+_ii
# count                  385.000000
# mean                254516.452883
# std                  51434.987870
# min                 185396.540000
# 25%                 224516.620000
# 50%                 245811.620000
# 75%                 263531.980000
# max                 445945.310000

# %%
df.head(2)
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0  20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1  20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
#
#                 reparticion  asignacion_por_cargo_i  aguinaldo_ii  \
# 0          Jefe de Gobierno                197745.8           0.0
# 1  Vicejefatura de Gobierno                197745.8           0.0
#
#    total_salario_bruto_i_+_ii observaciones
# 0                    197745.8           NaN
# 1                    197745.8           NaN

# %%
df.sort_values('aguinaldo_ii',ascending=True).head(2)
# Out:
#               cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 223  20-25641207-2  2019    8             AVOGADRO       ENRIQUE LUIS
# 232  20-23864572-8  2019    8             STRAFACE     FERNANDO DIEGO
#
#                                       reparticion  asignacion_por_cargo_i  \
# 223                         Ministerio de Cultura               263531.98
# 232  SECR General y de Relaciones Internacionales               263531.98
#
#      aguinaldo_ii  total_salario_bruto_i_+_ii observaciones
# 223           0.0                   263531.98           NaN
# 232           0.0                   263531.98           NaN

# %%
df['anio_mes'] = df['anio'] + df['mes']
df.head()
# Out:
#             cuil  anio  mes funcionario_apellido funcionario_nombre  \
# 0  20-17692128-6  2019    1    RODRIGUEZ LARRETA    HORACIO ANTONIO
# 1  20-17735449-0  2019    1             SANTILLI        DIEGO CESAR
# 2  27-24483014-0  2019    1                ACUÑA      MARIA SOLEDAD
# 3  20-13872301-2  2019    1             ASTARLOA      GABRIEL MARIA
# 4  20-25641207-2  2019    1             AVOGADRO       ENRIQUE LUIS
#
#                                         reparticion  asignacion_por_cargo_i  \
# 0                                  Jefe de Gobierno               197745.80
# 1                          Vicejefatura de Gobierno               197745.80
# 2              Ministerio de Educación e Innovación               224516.62
# 3  Procuración General de la Ciudad de Buenos Aires               224516.62
# 4                             Ministerio de Cultura               224516.62
#
#    aguinaldo_ii  total_salario_bruto_i_+_ii observaciones  anio_mes
# 0           0.0                   197745.80           NaN      2020
# 1           0.0                   197745.80           NaN      2020
# 2           0.0                   224516.62           NaN      2020
# 3           0.0                   224516.62           NaN      2020
# 4           0.0                   224516.62           NaN      2020

# %%
df_futbol = pd.read_csv('https://curso-data-science-verdadero-6to.s3.sa-east-1.amazonaws.com/csv/2024_BallonDorNominee.csv')
#[start,stop,step]
df_futbol = df_futbol.iloc[: , 1:]
df_futbol.head(2)
# Out:
#                league  season     team       player nation pos  age  born  \
# 0  ENG-Premier League    2324  Arsenal  Bukayo Saka    ENG  FW   21  2001
# 1  ENG-Premier League    2324  Arsenal  Declan Rice    ENG  MF   24  1999
#
#    Playing Time-MP  Playing Time-Starts  ...  Performance_misc-Crs  \
# 0               35                   35  ...                   181
# 1               38                   37  ...                    60
#
#    Performance_misc-Int  Performance_misc-TklW  Performance_misc-PKwon  \
# 0                    15                     35                       1
# 1                    44                     51                       0
#
#    Performance_misc-PKcon  Performance_misc-OG  Performance_misc-Recov  \
# 0                       0                    0                     155
# 1                       2                    0                     178
#
#    Aerial Duels-Won  Aerial Duels-Lost  Aerial Duels-Won%
# 0                23                 36               39.0
# 1                39                 43               47.6
#
# [2 rows x 236 columns]

# %% [markdown]
# # **Ejercicios**
# * Cuantos posibles ganadores hay?
# * Cuantos equipos tienen posibles ganadores del premio?
# * Cuantos paises tienen posibles ganadores del premio?
# * Cual es la edad promedio?
# * Cual es la posicion mas frecuente?
# * Cual es el jugador con mayor duelos aereos ganados? (Columna llamada Aerial Duels-Won)
# * Quien tiene mejor G+A? Pista ( Columna llamada Performance-G+A)
